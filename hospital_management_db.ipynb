# %%
# %load_ext sql
# %sql mysql+pymysql://root:toor@localhost/hospital_management

# %%
# %%sql
# select * from patients;
# Out:
#  * mysql+pymysql://root:***@localhost/hospital_management
# (pymysql.err.ProgrammingError) (1146, "Table 'hospital_management.patients' doesn't exist")
# [SQL: select * from patients;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
